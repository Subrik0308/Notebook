# %% [markdown]
# ## Содержание:
# - Знакомство с Jupyter Notebook
# - Функция вывода на экран (print)
# - Типы данных: Целые числа - INT (INTEGER)
# - Типы данных: Вещественные числа - FLOAT
# - Типы данных: Строки (текст) - STR (STRING)
# - Типы данных: логические или булевы переменные (boolean)
# - Логические выражения
# - Переменные
# - Команда input()
# - Форматирование строк (string formatting)
# - Функция print(): аргументы и параметры
# - Операторы и операнды
# - Условные конструкции
# - Встроенные функции
# - Встроенные модули
# - Ключевое слово as
# - Особенности импорта модулей
# - Цикл While
# - Инструкции, использующиеся внутри циклов
# - Вложенные циклы

# %% [markdown]
# # Знакомство с Jupyter Notebook

# %% [markdown]
# Jupyter Notebook (Юпитер-ноутбук) — это программа-блокнот для записи, передачи и запуска кода. Похож на блокнот, но работает в браузере.
#
# Существует возможность создавать ячейки, которые могут содержать как программный код, так и текст. Это пример ячейки с текстом! (Makdown)

# %%
# Пример ячейки с кодом. Символ # это комментарий
print("Привет мир!!!")

# %% [markdown]
# Многие текстовые редакторы включают сочетание клавиш для закомментирования нескольких строк кода. Выберите код и нажмите сочетание клавиш, чтобы превратить выбранные строки в комментарии.
#
# Visual Studio: нажмите `Ctrl` + `K` затем `Ctrl` + `C`
#
# Spyder IDE: `Ctrl` + `1`
#
# IDLE: `Alt` + `4`
#
# Записная книжка Jupyter: `Ctrl` + `/`
#
# PyCharm: `Ctrl` + `Shift` + `/`

# %%
a = 3  # Создаем переменную a и присваиваем ей значение 3
b = 0.5  # Создаем переменную a и присваиваем ей значение 0.5. Разделителем является точка, а не запятая

# %% [raw]
# По умолчанию тип ячейки Code, это можно увидеть на панели под меню. Чтобы изменить тип ячейки, нужно нажать на стрелочку вниз и выбрать нужный вариант. Всего вариантов три: Code, Markdown и Raw.
#
# Code: ячейка с кодом Python;
# Markdown: ячейка с размеченным текстом, язык разметки Markdown;
# Raw: неразмеченный «сырой» текст, без курсива/полужирного шрифта.

# %% [markdown]
# Более подробнее про написание текста с использованием Markdown можно посмотреть по этой [ссылке](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)
#
# Ниже приведены некоторые примеры форматирования текста и того, что можно сделать с использованием Markdown

# %% [markdown]
# Заголовки разных уровней.
#
# На входе:
#
#     # Заголовок 1
#     ## Заголовок 2
#     ### Заголовок 3
#
# На выходе:
#
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3

# %% [markdown]
# Выделять текст или часть текста с использованием курсива или полужирным написанием, подчеркивать или зачеркивать его.
#
#     *курсив*
# *курсив*
#
#     **полужирное начертание**
# **полужирное начертание**
#
#     <b>полужирное начертание</b>
# <b>полужирное начертание</b>
#
#     <ins>подчеркивание текста</ins>
# <ins>подчеркивание текста</ins>
#
#     <s>зачеркивание текста</s>
# <s>зачеркивание текста</s>
#
#     `выделение текста`
# `выделение текста`

# %% [markdown]
# Добавлять списки разного вида
#
# **Ненумерованный список**
#
# На входе:
#
#     * пункт 1
#
#     - пункт 2
#
#     <ul>
#         <li>пункт 3</li>
#     </ul>
#
# На выходе:
#
# * пункт 1
#
# - пункт 2
#
# <ul>
#     <li>пункт 3</li>
# </ul>

# %% [markdown]
# **Нумерованный список:**
#
# На входе:
#
#     1. Один...
#     2. Два...
#     3. Три...
#
# На выходе:
#
# 1. Один...
# 2. Два...
# 3. Три...

# %% [markdown]
# В текст можно добавлять <ins>ссылки</ins>
#
# Либо текст ссылки и саму ссылку: текст `[Anaconda](https://www.anaconda.com/)` даст ссылку [Anaconda](https://www.anaconda.com/)
#
# Либо саму ссылку как есть: текст `<https://www.anaconda.com/>` вернет ссылку <https://www.anaconda.com/>

# %% [markdown]
# Можно в текст добавлять изображаение:
#
# `![Ошибка загрузки](https://www.python.org/static/img/python-logo-large.c36dccadd999.png?1576869008)`
#
# ![Ошибка загрузки](https://www.python.org/static/img/python-logo-large.c36dccadd999.png?1576869008)

# %% [markdown]
# Если файл находится в публичном репозитории:
#
# `![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/01.jpg?raw=true)`
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/01.jpg?raw=true)

# %% [markdown]
# **Горячие клавиши**
#
# В Jupyter Notebook есть свои горячие клавиши, которые позволяют добавлять или удалять ячейки, менять их тип и так далее. Все полезные комбинации клавиш можно найти в меню (*Help - Keyboard Shortcuts*)

# %% [markdown]
# **Расположение файла**
#
# Для того чтобы найти куда Jupyter сохраняет ноутбуки — файлы с расширением `.ipynb`. Можно импортировать модуль *os* и узнать текущую рабочую папку (*current working directory*) — в ней будут лежать ноутбуки.

# %%
import os
os.getcwd()

# %%
os.listdir()  # Узнать список файлов и папок в текущей папке

# %% [markdown]
# # Функция вывода на экран (print)
#
# Функция `print` - нужна для того, чтобы производить выводить на экран
#
# Формат вызова: `print(<первое, что хотите вывести на экран>, <второе, что хотите вывести на экран>, ...)`
#
# То, что перечисляется внутри скобок и разделяется запятыми, называется *аргументами* или _входами_ функции

# %%
print('Hello, world!')
print(1)

# %% [markdown]
# Обратите внимание, что "Hello, world!" мы написали в кавычках, а единицу - нет. Это связанно с тем,
# что в программировании мы имеем дело с разными типами данных. И Python будет воспринимать текст как текст (строковую переменную), только в том случае, если мы его возьмем в кавычки (одинарные или двойные). А при выводе эти кавычки отображаться уже не будут (они служат знаком для Python, что внутри них - текст).
#
# `print()` - это функция, которая выводит то, что мы ей передадим. В других IDE это был бы вывод в терминал, а в Jupyter вывод напечатается под запускаемой ячейкой. Распознать функцию в питоне можно по скобкам после слова, внутри которых мы передаем аргумент, к которому эту функцию нужно применить (текст "Hello, world" или 1 в нашем случае).

# %%
print(Hello, world)

# %% [markdown]
# Написали без кавычек - получили ошибку. Обратите внимание, что очень часто в тексте ошибки есть указание на то, что именно произошло, какой тип ошибки нам встретился. Текст без кавычек Python воспринимает как название переменной, которую еще не задали. Кстати, если забыть закрыть или открыть кавычку (или поставить разные), то тоже поймаем ошибку.
#
# Очень важно писать комментарии к коду, чтобы тот, кто читает ваш код понимал, что вы хотели написать в данной части кода. Комментарии можно писать прямо в коде, они не повлияют на работу программы.

# %%
# Так выглядит комментарий - часть скрипта, которая не будет исполнена при запуске программы
# Каждую строку комментария мы начинаем со знака хэштега

'''
Это тоже комментарий - обычно выделение тремя апострофами мы используем для тех случаев, 
когда хотим написать длинный, развернутый текст.
'''

print('Hello, world')  # Здесь я с помощью функции принт печатаю текст

# %% [markdown]
# Обратите внимание, что в отличие от других IDE в Jupyter Notebook не всегда обязательно использовать print(), чтобы что-то вывести. Но не относитесь к этому как к стандарту для любых IDE.

# %%
"Hello, world"

# %%
2+3

# %% [markdown]
# Важная вещь в программирование, это задание переменных. Переменные - это контейнеры, которые хранят в себе информацию (текстовую, числовую, какие-то более сложные виды данных). В Python знаком присвоения является знак =

# %%
x = 'Hello, world!'
print(x)  # Результат вызова этой функции такой же, как выше, только текст теперь хранится внутри переменной

# %% [markdown]
# Python -  язык чувствительный к регистру. Поэтому, когда создаете/вызываете переменные или функции, обязательно используйте правильный регистр. Так, следующая строка выдаст ошибку.

# %%
print(X) # Мы создали переменную x, а X не существует

# %% [markdown]
# Еще раз обратим внимание на ошибку. *NameError: name 'X' is not defined* означает, что переменная с таким названием не была создана в этой программе. Кстати, обратите внимание, что переменные в Jupyter хранятся на протяжении всей сессии (пока вы работаете с блокнотом и не закрыли его), и могут быть созданы в одной ячейке, а вызваны в другой. Давайте опять попробуем обратиться к x.

# %%
print(x) # Работает!

# %% [markdown]
# # Типы данных: Целые числа - INT (INTEGER)

# %% [markdown]
# Знакомство с типа данных мы начнем с целых чисел. Если вы вдруг знакомы с другими языками программирования, то стоит отметить, что типизация в Python - динамическая. Это значит, что вам не нужно говорить какой тип данных вы хотите положить в переменную - Python сам все определит. Проверить тип данных можно с помощью функции `type()`, передав ей в качестве аргумента сами данные или переменную.
#
# ЦЕЛЫЕ ЧИСЛА (INT, INTEGER): 1, 2, 592, 1030523235 - любое целое число без дробной части.

# %%
print(type(2))

# %%
y = 2
print(type(2))
print(type(y))

# %% [markdown]
# Обратите внимание - выше мы вызвали функцию внутри функции.
# type(2) возвращает скрытое значение типа переменной (int для integer).
# Чтобы вывести это скрытое значение - мы должны его "напечатать".
#
# Самое элементарное, что можно делать в Python - использовать его как калькулятор. Давайте посмотрим, как
# он вычитает, складывает и умножает.

# %%
print(2 + 2)
print(18 - 9)
print(4 * 3)

# %%
print(2 + 2)

# %%
print(2+2)

# %% [markdown]
# С делением нужно быть немного осторожней. Существует два типа деления - привычное нам, которое даст в ответе дробь при делении 5 на 2, и целочисленное деление, в результате которого мы получим только целую часть частного.

# %%
print(5 / 2)  # В результате такого деления получается другой тип данных (float), подробнее о нем поговорим ниже
print(5 // 2)

# %% [markdown]
# А если нам надо как раз найти остаток от деления, то мы можем воспользоваться оператором модулю %

# %%
print(5 % 2)

# %% [markdown]
# Еще одна математическая операция, которую мы можем выполнять без загрузки специальных математических библиотек - это
# возведение в степень.

# %%
print(5**3)

# %% [markdown]
# Все то же самое работает и с переменными, содержащими числа.

# %%
a = 2
b = 3
print(a ** b)
# Изменится ли результат, если мы перезапишем переменную a?
a = 5
print(a ** b)

# %%
A = 10  # Заданы два числа A и B
B = 3
C = A // B  # Обозначим за C целую часть от деления A на B
print(C)  # Результат - 3
D = A % B  # Обозначим остаток от деления D
print(D)  # Результат - 1

# При делении 11 на -5 мы получим целую часть -3, а остаток -4
# При делении -11 на -5 мы получим целую часть 2, а остаток -1

# %% [markdown]
# Часто возникает ситуация, что мы считали какие-то данные в формате текста, и у нас не работают арифметические операции. Тогда мы можем с помощью функции `int()` преобразовать строковую переменную (о них ниже) в число, если эта строка может быть переведена в число в десятичной системе.

# %%
print(2 + '5')  # Ошибка, не сможем сложить целое число и строку

# %%
print(2 + int('5'))  # Преобразовали строку в число и все заработало

# %%
str(2)

# %%
int(2.6)

# %%
int('текст')  # Здесь тоже поймаем ошибку, потому что строка не представляет собой число

# %% [markdown]
# ### Задача
#
# С начала суток прошло x минут. Определите, сколько часов и минут будут показывать электронные часы в этот момент.
#
# **Вывод**
#
# Программа должна вывести два числа: количество часов (от 0 до 23) и количество минут (от 0 до 59).
#
# Учтите, что число x может быть больше, чем количество минут в сутках.

# %%
x = 150
ch = x // 60 % 24  # Вычисляем кол-во часов, задав диапазон 0-23
m = x % 60  # Вычисляем кол-во минут
print(ch, m)  # На входе - 150. Результат - 2 30

# %% [markdown]
# ### Задача
#
# Сейчас 23 часа. Сколько времени покажут часы через 8 часов?
#
# Если мы просто напишем: 23 + 8 и запустим программу, то получим 31. Часы 31 не показывают.
#
# Часы показывают что-то от 0 до 23. В сутках 24 часа, мы берем и считаем остаток от деления на 24. Результат - 7. То есть если сейчас 23:00, мы проводим 8 часов во сне, то когда мы просыпаемся, часы покажут 7.

# %%
print((23 + 8) % 24)

# %% [markdown]
# ### Задача

# %% [markdown]
# Дано число n. Необходимо отрезать от него k последних цифр. Если мы разделим число на 10, то будет отброшена последняя цифра, независимо от того, какой она была. Если разделим число на 100 - будет отброшено две последние цифры. Исходя из этого получается решение задачи: необходимо просто разделить число n на 10 в степени k.

# %%
n = int(input())
k = int(input())
print(n // 10 ** k)

# %% [markdown]
# ### Задача

# %% [markdown]
# Дано четырехзначное число. Определите, является ли его десятичная запись симметричной. Если число симметричное, то выведите 1, иначе выведет любое другое целое число. Число может иметь меньше четырех знаков, тогда нужно считать, что его десятичная запись дополняется слева нулями. Десятичная запись числа симметрична, если при прочтении слева направо и справа налево получается одно и то же число.

# %%
nv = int(input())
n0 = nv % 10
n1 = nv // 10 % 10
n2 = nv // 100 % 10
n3 = nv // 1000
nx = n0 * 1000 + n1 * 100 + n2 * 10 + n3
print((nv + 1) // (nx + 1) + (nv + 1) % (nx + 1))

# %% [markdown]
# ### Задача

# %% [markdown]
# На входе два числа, нужно вывести наибольшее из них. Числа - целые, от 1 до 1000.
#
# Исходя из имеющихся в нашем арсенале операций, а именно + - * // % **, что может однозначно сказать, что одно число больше другого? Например, целая часть от деления, если она > 0, говорит о том что одно число больше другого, а если равно 0, то меньше. Если взять левую часть формулы, то при неравных исходных числах, ее результат будет бОльшим числом, умноженным на коэффициент, во сколько раз больше это число второго, т.к. 'c' или 'd' будет равно 0, и второе слагаемое обнулится. А сумма в правой части даст этот же коэффициент, т.к. одно из слагаемых 0. Разделив получим ответ. Если числа равны, оба коэффициента будут по 1, и в результате мы просто разделим удвоенное число из левой части на 2 из правой.

# %%
a = int(input())
b = int(input())
c = a // b
d = b // a
print((a * c + b * d) // (c + d))

# %% [markdown]
# ### Задача

# %% [markdown]
# Необходимо проверить, делится ли число A на число B нацело. Использовать можно только арифметические операции. Вводятся два натуральных числа A и B. Выведите "YES", если A кратно B и "NO" в противном случае.

# %%
A = int(input())
B = int(input())
print('YES' * (0 ** (A % B)), end='')
print('NO' * (0 ** (0 ** (A % B))))

# %% [markdown]
# ### Задача

# %% [markdown]
# Даны два момента времени в пределах одних и тех же суток. Для каждого момента указан час, минута и секунда. Известно, что второй момент времени наступил не раньше первого. Выведите число секунд между этими моментами времени.
#
# На входе получаем шесть целых чисел. Первые три целых числа соответствуют часам, минутам и секундам первого момента, следующие три числа соответствуют второму моменту. Часы задаются числом от 0 до 23 включительно. Минуты и секунды — от 0 до 59.

# %%
H1 = int(input())
M1 = int(input())
S1 = int(input())
H2 = int(input())
M2 = int(input())
S2 = int(input())
# конвертируем в наименьшую величину - секунды - и складываем
sTotal1 = (H1 * 3600) + (M1 * 60) + S1
sTotal2 = (H2 * 3600) + (M2 * 60) + S2
print(sTotal2 - sTotal1)

# %% [markdown]
# ### Задача

# %%
# Задача сложить две стоимости товара, состоящие из рублей и копеек.

a = int(input())  # Задаём рубли
b = int(input())  # Задаём копейки
c = int(input())  # Задаём рубли
d = int(input())  # Задаём копейки
cost1 = a * 100 + b  # Умножаем, чтобы перевести рубли в копейки - в наименьшую единицу измерения
cost2 = c * 100 + d
totalCost = cost1 + cost2
print(totalCost // 100, totalCost % 100)  # Делим сумму для перевода в рубли и считаем остаток от деления - копейки

# %%
n1 = int(input())
n2 = str(n1) * 10  # Преобразуем число на входе в строку и получаем это число, повторённое десять раз
print(n2)
print(int(n2) ** 2)  # Преобразуем повторённое сто раз число обратно в цифру и возводим в квадрат

# %%
Sv = int(input())  # На входе - секунды. Преобразуем в число для вычислений
H = Sv // 3600 % 24  # Вычисляем кол-во часов
M1 = ((Sv % 3600) // 600) % 6  # Вычисляем кол-во десятков минут
M2 = ((Sv % 3600) // 60) % 10  # Вычисляем кол-во единиц минут
S1 = ((Sv * 10) // 100) % 6  # Вычисляем кол-во десятков секунд
S2 = (Sv % 60) % 10  # Вычисляем кол-во единиц секунд
print(H, ':', M1, M2, ':', S1, S2, sep='')

# %% [markdown]
# # Типы данных: Вещественные числа - FLOAT

# %% [markdown]
# На что обратить внимание - числа с десятичной частью, например, $1.43$, в отличие от Excel, в Python пишутся не через запятую `,`, а через точку `.`.
#
# Почувствуйте разницу:

# %%
print(2,6 // 2)  # Печатает два числа
print(2,   6 / 2)  # И так тоже два числа, пробел в данном случае неважен
print(2.6 / 2)  # Печатает одно число

# %%
0.2 + 0.1  # Результат сложения будет выведен равным 0.30000000000000004

# %% [markdown]
# Еще результат может выводиться в довольно странном формате:

# %%
3.1 * 10 ** 2

# %% [markdown]
# Дело в том, что во время вычислений, числа переводятся в бинарную систему. Это явление встречается во многих языках програмирования. Это нужно иметь ввиду и при необходимости обрабатывать результат вычислений перед дельнейшими действиями.

# %% [markdown]
# # Типы данных: Строки (текст) - STR (STRING)

# %% [markdown]
# С помощью `print` можно печатать не только числа. Например, текст:
# - текстовая строка в питоне -- это любое выражение, заключённое в двойные `"` или одинарные `'` кавычки
# - с точки зрения пользователя, ничем не отличается от привычного текста
#
# Например:

# %%
print("Моё имя:")

# %%
print('кавычки""')

# %%
print('Первое'+'занятие')

# %%
print('Первое '+' '+'занятие')

# %%
'слово '*3

# %%
print('у меня'+' '+ 'дневник '*3)

# %%
print('У меня '+ 'много книг \n '*10)

# %%
# Сохранение строк в переменные и их сложение

phrase = 'Hasta la vista'
who = '"Baby"'  # Двойные внутри одинарных кавычек (и наоборот) теряют "силу" и просто выводятся
print(phrase + ', ' + who + '!')  # Результат - Hasta la vista, "Baby"!

# %% [markdown]
# На что обратить внимание:
# - выражение `1` это число
# - выражение `'1'` это строка
#
# Почувствуйте разницу:

# %%
print(1 + 2)  # Печатает результат сложения
print('1' + '2')  # Результат - числа "склеены" - 12. Склеивание строк называется конкатенация
print(str(1) + str(2))  # Функция str преобразует аргумент в строку

# %% [markdown]
# В строке '2 + 3 =' нет пробела после знака =. Пробел появляется автоматически между параметрами функции print.

# %%
print('2 + 3 =', 2 + 3)  # Результат - 2 + 3 = 5

# %%
p = int(input())  # Задача - вывести на экран p пингвинов.
print(('   _~_    ') * p)
print(('  (o o)   ') * p)
print((' /  V  \  ') * p)
print(('/(  _  )\ ') * p)
print(('  ^^ ^^   ') * p)

# %% [markdown]
# ### Индексирование строк

# %%
s = '0123 5678 abcd fghi'

# %%
s[0]

# %%
s[1]

# %%
s[-6]

# %% [markdown]
# Срез указывается следующим образом - [ начало (включительно) : конец (не включительно!) : шаг ]

# %%
print(s[8:16])

# %%
print(s[1::2])

# %%
print(s[::-1])

# %%
print("**** **** **** " + s[15:19])

# %% [markdown]
# # Типы данных: логические или булевы переменные (boolean)
#
# Следующий тип данных - это логические переменные. Логические переменные могут принимать всего два значения - `истина (True)` или `ложь (False)`. В Python тип обознчается `bool`.

# %%
print(type(True), type(False))

# %% [markdown]
# Логические переменные чаще всего используется в условных операторах if-else и в цикле с остановкой по условию while.
#
# Обратите внимание, что True и False обязательно пишутся с большой буквы и без кавычек, иначе можно получить ошибку.

# %%
print(type('True'))  # тип str - строковая переменная
print(true)  # Ошибка, Python думает, что это название переменной

# %% [markdown]
# Как и в случае чисел и строк, с логическими переменными работает преобразование типов. Превратить что-либо в логическую переменную можно с помощью функции `bool()`.
#
# Преобразование чисел работает следующим образом - 0 превращается в False, все остальное в True.

# %%
print(bool(0))
print(bool(23.5))
print(bool(-10))

# %%
# Операция проверки введённого числа на чётность. Если число чётное - True, если нет - False.
q = int(input())
w = q % 2 == 0
print(w)

# %% [markdown]
# Пустая строка преобразуется в False, все остальные строки в True.

# %%
print(bool(''))
print(bool('Hello'))
print(bool(' '))  # Даже строка из одного пробела - это True
print(bool('False'))  # И даже строка 'False' - это True

# %% [markdown]
# И при необходимости булеву переменную можно конвертировать в int.

# %%
print(int(True))
print(int(False))

# %% [markdown]
# # Логические выражения
#
# Давайте посмотрим, где используется новый тип данных.
#
# Мы поработаем с логическими выражениями, результат которых - булевы переменные.
#
# Логические выражения выполняют проверку на истинность, то есть выражение равно True, если оно истинно, и False, если ложно.
#
# В логических выражениях используются операторы сравнения:
# - ==  (равно)
# - !=  (не равно)
# - \>  (больше)
# - <  (меньше)
# - \>=  (больше или равно)
# - <=  (меньше или равно)
#
# Приоритет сравнения меньший, чем у арифметических операций. Между собой они равны.

# %%
print(1 == 1)
print(1 != '1') 
c = 1 > 3
print(c)
print(type(c))
x = 5
print(1 < x <= 5)  # Можно писать связки цепочкой

# %% [markdown]
# Логические выражения можно комбинировать с помощью следующих логических операторов (в порядке убывания приоритета):
#
# - логическое `И (and)` - выражение истинно, только когда обе части истинны, иначе оно ложно
# - логическое `ИЛИ (or)` - выражение ложно, только когда обе части ложны, иначе оно истинно
# - логическое `отрицание (not)` - превращает True в False и наоборот
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/02.png?raw=true)
#
# Приоритет логических операций ниже, чем у сравнений и, соответственно, ниже арифметических операций.

# %%
print((1 == 1) and ('1' == 1))
print((1 == 1) or ('1' == 1))
print(not(1 == 1))
print(((1 == 1) or ('1' == 1)) and (2 == 2))

# %% [markdown]
# ### Задача
# Вася в Италии
#
# Вася уехал учиться по обмену на один семестр в Италию. Единственный магазин в городе открыт с 6 до 8 утра и с 16 до 17 вечера (включительно). Вася не мог попасть в магазин уже несколько дней и страдает от голода. Он может прийти в магазин в X часов. Если магазин открыт в X часов, то выведите True, а если закрыт - выведите False.
#
# В единственной строке входных данных вводится целое число X, число находится в пределах от 0 до 23.
#
# **Ввод**
#
# Целое число X, число находится в пределах от 0 до 23
#
# **Вывод**
#
# True или False
#
# **Примеры**
#
# Тест 1
# **Входные данные:**
# 16
#
# **Вывод программы:**
# True

# %%
X = 7
time1 = 6 <= X and X <= 8
time2 = 16 <= X and X <= 17
print(time1 or time2)

# %% [markdown]
# # Переменные
#
# **Имя переменной** должно начинаться с маленькой латинской буквы, должно быть осмысленным и не должно превышать по длине 10-15 символов. Если логичное имя переменной состоит из нескольких слов, то можно записывать его с помощью camelTyping (каждое новое слово кроме первого должно быть записано с большой буквы).
#
# В питоновском стандарте PEP-8 предлагается называть переменные, используя подчеркивания: variable_name. Имя переменной не должно начинаться с числа или нижнего подчёркивания, это считается дурным тоном.
#
# В Python мы можем записывать в переменные какие-либо значения (или наборы значений):

# %% [markdown]
# myName
#
# my_name

# %%
number = 5
my_name = 'Иван'
print(number)
print(my_name)

# %% [markdown]
# Если мы будем реализовывать какие-то действия с переменными, то они будут осуществляться со значениями, которые записаны в эти переменные:

# %%
print(number*my_name)

# %%
speed = 108
time = 12
dist = speed * time
print(dist)  # Результат - 1296

# %% [markdown]
# `%whos` - команда выводит все переменные, которые на данный момент в памяти, в текущем блокноте юпитера.

# %% [markdown]
# # Команда input()

# %% [markdown]
# Функция `input()` позволяет получить данные от пользователя с помощью ввода данных с клавиатуры.

# %%
print('Как тебя зовут?')
name = input()
print('Привет,', name)

# %%
name = input('Как тебя зовут?')
print('Привет,', name)

# %%
age = int(input("Введите ваш возраст \n"))
print(age * 2)

# %%
temp = float(input("Введите температуру "))
print(temp > 20)

# %% [markdown]
# Можно задать несколько переменных, но их количеству должно соответствовать вводу.

# %%
a, b = input().split()  # По умолчанию, разграничителем служит пробел
print(a)
print(b)

# %% [markdown]
# По умолчанию разделителем является пробел, но можно изменить.

# %%
a, b = input().split(",")
print(a)
print(b)

# %%
a, b = input().split(";")
print(a)
print(b)

# %% [markdown]
# По умолчанию ввод вводится типом string. С использованием функции `map()` можно изменить тип данных.

# %%
a, b = int(input().split())  # Работать не будет
print(a)
print(b)

# %%
a, b = map(int,input().split())  # Работать будет
print(a + b)

# %% [markdown]
# ### Задача
#
# Задача аналогичная часам, но с другим условием - максимум 256, т.е. диапазон чисел 0-255.
#
# Число 10 на входе даст 10 на выходе, а вот число 500 даст на выходе 244 (500 - 256 = 244).
#
# При переходе через максимальное значение, счетчик обнуляется.

# %%
n = int(input())
print(n % 256)

# %% [markdown]
# ### Задача
#
# Улитка ползет по вертикальному шесту высотой H метров, поднимаясь за день на d1 метров, а за ночь спускаясь на d2 метров. На какой день улитка доползет до вершины шеста? На вход целые H, d1, d2. Гарантируется, что d1>d2≥0.

# %%
H = int(input())  # длина отрезка
d1 = int(input())  # дневной шаг
d2 = int(input())  # ночной шаг назад
step = d1 - d2  # суточный шаг
L = (H - d1)  # длина без последнего шага
print(((L + step - 1) // step) + 1)

# %% [markdown]
# Длина без последнего шага плюс суточный шаг минус шаг на 1 пункт (делается для ситуации с нечётным суточным шагом). Минус шаг на 1 пункт, при суточном шаге = 1, даёт просто длину (L(+1-1)), без последнего шага в первой части формулы. Далее мы просто делим эту длину на количество суточных шагов (step) и добавляем последний шаг (+ 1) получая ответ.
# Минус шаг на 1 пункт, при суточном шаге > 1, даёт:
# - при чётном суточном шаге, минус шаг на 1 пункт можно было бы не делать, например при данных 10 5 1 суточный шаг 4
#
# 8 или 9 // 4 = разницы нет
# - при нечётном суточном шаге минус шаг на 1 пункт необходим, например при данных 10 4 1 суточный шаг 3
#
# 8 // 3 = 2, а вот 9 // 3 = 3 потому что к длине без последнего шага (L) добавляется суточный шаг (step), а потом мы делим это на сам суточный шаг (step). Без отнятой единицы (-1) сверх нужного результата мы получим ещё один шаг (step) (+1). Нам же необходимо на данном этапе только округлить вверх (нужно не во всех случаях).
#
# (L + step - 1) = здесь получаем длину отрезка без последнего шага округлённую в большую сторону.
#
# Далее производим деление без остатка (// чтобы убрать округление вверх) на суточный шаг, в результате чего получаем количество дней за которые улитка проходит длину без последнего шага (L). Добавляем ещё один день (+1) в котором улитка достигает конца отрезка. То же решение, но компактней:

# %%
H = int(input())
d1 = int(input())
d2 = int(input())
print((((H - d1) + (d1 - d2) - 1) // (d1 - d2)) + 1)

# %% [markdown]
# ### Задача

# %%
# На входе числа A и B — натуральные, не превышают 1000.

A = (int(input()) % 1000)  # "A" школьников делят 'B' яблок поровну, не делящийся остаток остается в корзинке
B = (int(input()) % 1000)  # Сколько яблок достанется каждому школьнику?
print(B // A)  # На входе 3 и 14. Результат - 4

# %%
A = (int(input()) % 1000)  # "A" школьников делят 'B' яблок поровну, не делящийся остаток остался в корзинке
B = (int(input()) % 1000)  # Сколько яблок осталось в корзинке?
print(B % A)  # На входе 3 и 14. Результат - 2

# %%
# За день машина проезжает d1 километров. Сколько дней нужно, чтобы проехать маршрут длиной d2 километров?

d1 = int(input())  # На входе - сколько километров проезжает машина за день
d2 = int(input())  # На входе - длинна маршрута, которую необходимо преодолеть
print((d1 + d2 - 1) // d1)

# %%
# На входе имеем положительное число. Задача найти число десятков в нём, или 0, если число меньше 10.

print(int(input()) * 10 // 100)  # На входе - 542. Результат - 54

# %%
# Задача посложнее - найти цифру, стоящую в разряде десятков.

print(int(input()) * 10 // 100 % 10)  # На входе - 273. Результат - 7

# %%
# На входе имеем положительное число. Задача найти последнюю цифру от введённого числа.

n = (int(input())) % 1000  # Вводится целое положительное число. Ограничиваем, чтобы оно не превышало 1000
print(n % 10)  # Ограничиваем диапазон 0-9 и получаем на выходе последнюю цифру

# %%
# Дано трехзначное число. Найдите сумму его цифр.

n1 = (int(input())) % 1000  # Ограничиваем число на входе тремя знаками
n2 = n1 // 100  # Вычисляем количество сотен
n3 = (n1 // 10) % 10  # Вычисляем количество десятков с ограничением диапазона 0-9
n4 = n1 % 10  # Вычисляем единицы в диапазоне 0-9
print(n2 + n3 + n4)  # Складываем полученные значения

# %%
# Дано целое число L, не превышающее 1000. Выведите следующее за ним четное число.

L = (int(input()) % 1000)  # Ограничиваем диапазон чисел 0-999
print(L + 2 - (L % 2))  # К числу на входе прибавляем 2 и вычитаем остаток от деления в диапазоне 0-1

# На входе - 7. Результат - 7+2-(7%2)=9-1=8. // На входе - 8. Результат - 8+2-(8%2)=10-0=10

# %% [markdown]
# # Форматирование строк (string formatting)
# Для начала попросим пользователя ввести свое имя и возраст.

# %%
name = input("Введите Ваше имя: ")
age = int(input("Введите Ваш возраст: "))  # Возраст будет целочисленным

# %% [markdown]
# Теперь выведем на экран сообщение вида:
#
# `Ваше имя: `имя`. Ваш возраст: `возраст`.`
#
# Но сначала нам необходимо задать тип данных, которые будем подставлять в шаблон.
#
# Имя (переменная name) – это строка (string), а возраст (переменная age) – это целое число (integer).

# %%
result = "Ваше имя: %s. Ваш возраст: %i." % (name, age)
print(result)

# %% [markdown]
# `Оператор %` в строке указывает место, на которое будет подставляться значение, а буква сразу после процента – сокращённое название типа данных (**s – от string, i – от integer, f - от float**).
#
# После кавычек необходимо поставить % и в скобках перечислить названия переменных, значения которых мы будем подставлять, в том же порядке.
#
# Примечание: не теряйте часть с переменными после самой строки. Иначе получится просто вывод символов:

# %%
print("Ваше имя: %s. Ваш возраст: %i.")

# %% [markdown]
# Важно помнить, что если мы забудем указать какую-то из переменных, мы получим ошибку: Python не будет знать, откуда брать нужные значения.

# %%
print("Ваше имя: %s. Ваш возраст: %i." % (name))

# %% [markdown]
# Кроме того, создавая такие текстовые шаблоны, нужно обращать внимание на типы переменных, значения которых мы подставляем.

# %%
print("Ваше имя: %s. Ваш возраст: %s." % (name, age))  # Так сработает, int будет переведен в str

# %%
print("Ваше имя: %i. Ваш возраст: %s." % (name, age))  # А так нет, т.к. текст невозможно перевести в int

# %% [markdown]
# В первом случае код сработал: Python легко смог превратить целочисленный возраст в строку (два %s вместо %s и %i). Во втором случае все иначе. Превратить строку, которая состоит из букв (name) в целое число никак не получится, поэтому Python выдал ошибку.
#
# Попробуем подставить дробное число (с плавающей точкой - float):

# %%
height = float(input("Введите Ваш рост (в метрах): "))
print("Ваш рост: %f м." % height)

# %% [markdown]
# По умолчанию при подстановке значений типа float Python выводит число с шестью знаками после запятой. Но мы можем скорректировать вывод. Перед f нужно поставить точку и указать число знаков после запятой, которое мы хотим вывести:

# %%
print("Ваш рост: %.2f м." % height)  # Например, два

# %% [markdown]
# В случае, если указанное число знаков после запятой меньше, чем есть на самом деле (как в ячейке выше), происходит обычное арифметическое округление.
#
# Рассмотренный выше способ форматирования строк – не единственный. Он довольно стандартный, но при этом немного устаревший. В Python 3 есть другой способ ‒ форматирование с помощью метода `.format()`. Кроме того, в Python 3.6 и более поздних версиях появился еще более продвинутый способ форматирования строк ‒ `f-strings` (formatted string literals).
#
# F-strings очень удобны и просты в использовании: вместо % и сокращённого названия типа в фигурных скобках внутри текстового шаблона нужно указать название переменной, из которой должно подставляться значение, а перед всей строкой добавить f, чтобы Python знал, что нам нужна именно f-string.

# %%
print(f"Ваше имя: {name}. Ваш возраст: {age}. Рост: {height:.2f}")

# %% [markdown]
# Альтерантивой такого кода будет следующий синтаксис. Здесь переменные вставятся в порядке "упоминания" в строке.

# %%
print("Ваше имя: {}. Ваш возраст: {}".format(name, age))

# %% [markdown]
# Форматирование дробей добавляем так.

# %%
print("Ваше имя: {}. Ваш возраст: {}. Рост: {:.2f}".format(name, age, height))

# %% [markdown]
# Если указали формат переменной (.2f, например, ожидает float), то следим за порядком.

# %%
print("Ваше имя: {}. Ваш возраст: {}. Рост: {:.2f}".format(age, height, name))

# %% [markdown]
# Порядок заполнения можно указывать с помощью нумерации. Одну и тоже переменную можно использовать несколько раз.

# %%
print("Ваше имя: {2}. Ваш возраст: {0}. Рост: {1:.2f}. Все верно, {2}?".format(age, height, name))

# %% [markdown]
# Также при форматировании строк можно использовать результаты вычислений и результаты работы методах (о  них немного позже).
#
# name.upper() в примере делает все символы строки name заглавными.

# %%
print(f"Ваше имя: {name.upper()}. Ваш возраст: {2023-1988}. Рост в футах: {height * 100 / 30.48 :.2f}")

# %% [markdown]
# # Функция print(): аргументы и параметры

# %%
print('2 + 3 =', 2 + 3)
z = 5
print('2 + 3 =', z)

# %% [markdown]
# У функции print есть параметры. Параметры - это такие свойства функций, которые задают значение невидимых нам аргументов внутри функции. Так существует параметр `sep (separator)`, благодаря которому мы можем менять тип разделителя между аргументами print. В качестве разделителя может выступать любая строка. Сравните:

# %%
print('1', '2', '3')
print('1', '2', '3', sep='.')
print('1', '2', '3', sep=', ')
print('1', '2', '3', sep='')
print('1', '2', '3', sep='\t')
print('1', '2', '3', sep='\n')

# %% [markdown]
# Параметр `end` задает то, что будет выведено в конце исполнения функции print. По умолчанию там стоит
# невидимый символ '\n', который осуществляет переход на новую строку. Мы можем заменить его на любую строку.
# Если мы хотим сохранить переход на новую строку - то обязательно прописываем наш невидимый символ внутри
# выражения.

# %%
print('1', '2', '3', sep='.', end='!')
print('2')  # Строки слились

# %%
print('1', '2', '3', sep='.', end='!\n')
print('2')  # Вывод на новой строке

# %%
print('1', '2', '3', sep='.', end='!')
print()
print('2')  # Вывод на новой строке

# %% [markdown]
# **Использование бэкслеша** перед символом называется экранирование. Также существуют и другие символы, которые требуют бэкслеша перед собой. Например, это кавычки \' и \'' (использование бэкслеша просто необходимо, если в строке используются оба типа кавычек), а также, собственно, символ бэкслеша, который надо записывать как \\.
#
# В случае считывания с помощью input, символы в консоли экранировать не нужно.

# %% [markdown]
# # Операторы и операнды
#
# Выше мы изучили булевы переменные. Их особенность в том, что они могут принимать всего два значения:
#
# - True, которое можно сравнить с 1;
# - False, которое сравнимо с 0.
#
# `Операторы` — это некий функционал, производящий какие-либо действия, который может быть представлен в виде символов, например «+», или специальных зарезервированных слов.
#
# Операторы могут производить некоторые действия над данными, и эти данные называются `операндами`.
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/03.png?raw=true)
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/04.jpg?raw=true)
#
# Пусть у нас есть данные о росте трех студентов в метрах (тип float). Для хранения этих данных используются три переменные:

# %%
# Создаём 3 переменные, в которых содержится рост трех студентов

student_01 = 1.64
student_02 = 1.79
student_03 = 1.79

# %% [markdown]
# Давайте сравним прибыль компании на каждый год между собой.

# %%
# Проверяем равенство роста 1 и 2 студента
print(student_01 == student_02)
# False

# Проверяем равенство роста 2 и 3 студента
print(student_02 == student_03)
# True

# %% [markdown]
# # Условные конструкции
#
# Условные конструкции – конструкции с операторами условия. Условная конструкция обычно предполагает «развилку»: если условие выполняется, то должен выполняться один набор действий, если нет – другой набор действий.
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/05.png?raw=true)
#
# Напишем программу, которая будет просить пользователя ввести целое число, и если это число менее 10, на экран будет выводиться сообщение "Меньше 10".

# %%
x = int(input("Введите число: "))
if x < 10:
    print('Меньше 10')

# %% [markdown]
# Теперь дополним программу, она будет просить пользователя ввести целое число, и если это число менее 10, на экран будет выводиться сообщение "Меньше 10", иначе – "Больше 10". Это конструкция `if-else`.

# %%
x = int(input("Введите число: "))
if x < 10:
    print("Меньше 10")
else:
    print("Больше 10")

# %% [markdown]
# В части с if мы прописываем условие, в зависимости от которого Python будет делать выбор, что выводить на экран, а после двоеточия перечисляем действия, которые будут выполняться в случае, если x удовлетворяет условию. В части с else мы уже не пишем никакого условия – оператор else сам по себе означает «в случае, если условие в выражении с if не выполнено».
#
# Часть с else является необязательной: программа может существовать только с условием if. Тогда в случае невыполнения условия ничего происходить не будет, Python просто перейдет к следующим строкам кода.
#
# Как быть, если условий несколько? Например, мы просим пользователя ввести число, и если число больше 10, на экране должно быть сообщение "Больше 10", если ровно 10 – "Равно 10", если меньше – "Меньше 10". Условные конструкции можно вкладывать друг друга, главное не забывать при этом про отступы.
#
# Сдвигать части кода можно при помощи горячих клавиш:
#
# Ctrl + ] -- вправо
#
# Ctrl + [ -- влево

# %%
x = int(input("Введите число: "))
if x < 10:
    print("Меньше 10")
else:
    if x == 10:
        print("Равно 10")
    else: 
        print("Больше 10")

# %% [markdown]
# Можно воспользоваться оператором `elif`, который по смыслу является сочетанием `else + if`: если предыдущее условие невыполнено, то, нужно проверить следующее условие, и если оно тоже не выполнено, то уже перейти к ветке с else.
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/06.png?raw=true)

# %%
x = int(input("Введите число: "))
if x < 10:
    print("Меньше 10")
elif x == 10:
    print("Равно 10")
else: 
    print("Больше 10")

# %% [markdown]
# Ответвлений с elif может быть несколько: сколько условий, столько и выражений с elif.
#
# Законный вопрос: а можно ли обойтись совсем без elif, просто записав несколько выражений с if? Тут все зависит от ситуации. Иногда решения использовать elif и if, не меняя остальной код, будут равнозначными. Если мы перепишем код в примере выше, заменив elif на if, ничего не изменится, так как условия будут проверяться последовательно в любом случае: если число меньше 10, будет выведено слово «Мало», если нет – программа перейдет к следующему условию, и так далее.
#
# В случае, когда условия как-то связаны между собой, нужно быть более внимательными. Рассмотрим такой пример.
#
# **Случай 1.**

# %%
mark = int(input("Введите оценку: "))

# %%
if mark < 6:
    print("Плохо")
elif mark == 10:
    print("Отлично")
elif mark < 10:
    print("Это нормально")

# %% [markdown]
# Если оценка меньше 10, мы выводим на экран сообщение "Это нормально", если нет, то проверяем, равна ли она 10: если да, то выводим "Отлично", если нет – ничего не делаем. При этом, *после* всех этих действий делаем дополнительную проверку: если оценка меньше 6, выводим "Плохо".
#
# **Случай 2.**

# %%
if mark == 10:
    print("Отлично")
elif mark < 10:
    print("Это нормально")
elif mark < 6:
    print("Плохо")

# %% [markdown]
# Если оценка меньше 10, мы выводим на экран сообщение "Это нормально", если нет, то проверяем, равна ли она 10: если да, то выводим "Отлично", если нет – сравниваем ее с 6. Если оценка меньше 6, выводим "Плохо".
#
# Во втором случае не вывелось сообщение "Плохо" потому что из-за второго elif мы попросту до него не дошли.
#
# Напишем программу по переводу из 10-балльной шкалы в 5-балльную: оценка 8-10 баллов – «отлично», 6 - 7 – «хорошо», 4 - 5 – «удовлетворительно», ниже 4 – «плохо».
#
# **Решение 1:** несколько вложенных условий с оператором `elif`

# %%
grade = 10
if grade > 7:
    print("Отлично")
elif grade > 5:
    print("Хорошо")
elif grade > 3:
    print("Удовлетворительно")
else:
    print("Плохо")

# %% [markdown]
# **Решение 2:** несколько сложных условий с `if`

# %%
grade = 7
if grade > 7:
    print("Отлично")
if (grade > 5) and (grade <= 7):
    print("Хорошо")
if (grade > 3) and (grade <= 5):
    print("Удовлетворительно")
if grade <= 3:
    print("Плохо")

# %% [markdown]
# Могли бы мы использовать `else` вместо последнего условия с `if`? Давайте проверим!

# %%
grade = 7
if grade > 7:
    print("Отлично")
if (grade > 5) and (grade <= 7):
    print("Хорошо")
if (grade > 3) and (grade <= 5):
    print("Удовлетворительно")
else:
    print("Плохо")

# %% [markdown]
# ### Задача
#
# Реализуeм следующую программу:
#
# * В переменную time считывается целое число (время суток от 0 до 24).
# * Если время от 8 до 22 включительно, то программа печатает "Бодрствуем!", иначе — "Время спать!".

# %%
time = int(input())
if 8 <= time <= 22:
    print("Бодрствуем!")
else:
    print("Время спать!")

# %% [markdown]
# ### Задача
#
# Распродажа
#
# В магазине проходит акция:
#
# - На все товары за 1000 рублей и дешевле скидка 15%
# - На все товары дороже 1000, но не дороже 5000 рублей скидка 20%
# - На все товары дороже 5000 рублей скидка 25%
#
# **Ввод**
#
# Целое неотрицательное число - цена товара в рублях
#
# **Вывод**
#
# Целое неотрицательное число - скидка на товар в рублях

# %%
price = int(input())
if price <= 1000:
    print(int(price * 0.15))
elif price <= 5000:
    print(int(price * 0.2))
else:
    print(int(price * 0.25))

# %% [markdown]
# ### Задача
#
# Разовая поездка на метро стоит 70 рублей, проездной на 30 дней — 2500 рублей. Валя подсчитала, сколько она совершает поездок за 30 дней, помогите ей понять, чем выгоднее пользоваться — проездным или разовыми поездками.
#
# **Ввод**
#
# Целое положительное число — количество поездок Вали на метро за 30 дней
#
# **Вывод**
#
# Строка "Выгоднее разовые поездки" или "Выгоднее проездной" в зависимости от того, что выгоднее.

# %%
n = int(input())
if n * 70 < 2500:
    print("Выгоднее разовые поездки")
else:
    print("Выгоднее проездной")

# %% [markdown]
# ### Задача
#
# Вводятся 4 числа - координаты клеток на шахматной доске. Если они одного цвета, то выводит YES, если разного – то NO. Если нарисовать доску, то закономерность будет видна - если вычислить остаток от деления на 2 суммы или разницы координат клетки, будет ясно, что у белых клеток остаток будет 1, а у чёрных - 0.

# %%
v1 = int(input())
g1 = int(input())
v2 = int(input())
g2 = int(input())
x = (v1 - g1) % 2
y = (v2 - g2) % 2
if x == y:
    print('YES')
else:
    print('NO')

# %% [markdown]
# ### Задача
#
# Шахматный король ходит по горизонтали, вертикали и диагонали, но только на 1 клетку. Даны две различные клетки шахматной доски, определите, может ли король попасть с первой клетки на вторую одним ходом. На входе четыре числа от 1 до 8 каждое - номер столбца и номер строки сначала для первой, потом для второй клетки. Необходимо вывести YES, если из первой клетки ходом короля можно попасть во вторую или NO, в противном случае.

# %%
v1 = int(input())
g1 = int(input())
v2 = int(input())
g2 = int(input())
if (v1 - 1) == v2 or (v1 == v2) or (v1 + 1) == v2:
    if (g1 - 1) == g2 or (g1 == g2) or (g1 + 1) == g2:
        print('YES')
    else:
        print('NO')
else:
    print('NO')

# %% [markdown]
# ### Задача
#
# Дано три числа. Упорядочите их в порядке неубывания. Программа должна считывать три числа a,b,c, затем необходимо менять их значения так, чтобы стали выполнены условия a≤b≤c и вывести тройку a,b,c. Дополнительные ограничения: нельзя использовать дополнительные переменные.

# %%
a, b, c = int(input()), int(input()), int(input())
if a <= b <= c:
    print(a, b, c)
elif b <= a <= c:
    print(b, a, c)
elif c <= a <= b:
    print(c, a, b)
elif b <= c <= a:
    print(b, c, a)
elif c <= b <= a:
    print(c, b, a)
elif a <= c <= b:
    print(a, c, b)

# %%
# Результат применения функции (a,b)=(b,a):

a = 2
b = 1
a, b = b, a
print(a, b)  # Выведет 1 2

# %%
# Вышенаписанная задача решена с применением функции (a,b)=(b,a):

a, b, c = int(input()), int(input()), int(input())
if a <= b <= c:
    print(a, b, c)
elif a <= c <= b:
    (c, b) = (b, c)
    print(a, b, c)
elif b <= a <= c:
    (b, a) = (a, b)
    print(a, b, c)
elif b <= c <= a:
    (b, a) = (a, b)
    (c, b) = (b, c)
    print(a, b, c)
elif c <= b <= a:
    (c, a) = (a, c)
    print(a, b, c)
elif c <= a <= b:
    (c, a) = (a, c)
    (b, c) = (c, b)
    print(a, b, c)

# %% [markdown]
# ### Задача
#
# За многие годы заточения узник замка Иф проделал в стене прямоугольное отверстие размером D×E. Замок Иф сложен из кирпичей, размером A×B×C. Определите, сможет ли узник выбрасывать кирпичи в море через это отверстие (очевидно, стороны кирпича должны быть параллельны сторонам отверстия).
#
# Для решения необходимо сначало упорядочить размеры кирпича в порядке возрастания, затем сравнить с дырой в стене.

# %%
a, b, c = int(input()), int(input()), int(input())
d, e = int(input()), int(input())
if a <= c <= b:
    (c, b) = (b, c)
elif b <= a <= c:
    (b, a) = (a, b)
elif b <= c <= a:
    (b, a) = (a, b)
    (c, b) = (b, c)
elif c <= b <= a:
    (c, a) = (a, c)
elif c <= a <= b:
    (c, a) = (a, c)
    (b, c) = (c, b)
if (a <= d and b <= e) or (a <= d and c <= e) or (b <= d and c <= e):
    print('YES')
else:
    print('NO')

# %% [markdown]
# ### Задача
#
# Есть две коробки, первая размером A₁×B₁×C₁, вторая размером A₂×B₂×C₂. Определите, можно ли разместить одну из этих коробок внутри другой, при условии, что поворачивать коробки можно только на 90 градусов вокруг ребер. На входе числа A₁,B₁,C₁,A₂,B₂,C₂. Программа должна вывести одну из следующих строчек: Boxes are equal, если коробки одинаковые.
#
# The first box is smaller than the second one, если первая коробка может быть положена во вторую.
#
# The first box is larger than the second one, если вторая коробка может быть положена в первую.
#
# Boxes are incomparable, во всех остальных случаях.
#
# з.ы. В математической вселенной, если некоторые стороны коробок равны - они могут быть помещены друг в друга.
#
# тест 1 - 1, 2, 3, 3, 2, 1 - вывод 'Boxes are equal'
#
# тест 2 - 2, 2, 3, 3, 2, 1 - вывод 'The first box is larger than the second one'
#
# Для начала упорядочиваем размеры сторон коробок в порядке возрастания, затем перебором сравниваем их.

# %%
a1, b1, c1 = int(input()), int(input()), int(input())
a2, b2, c2 = int(input()), int(input()), int(input())
if a1 <= c1 <= b1:
    (c1, b1) = (b1, c1)
elif b1 <= a1 <= c1:
    (b1, a1) = (a1, b1)
elif b1 <= c1 <= a1:
    (b1, a1) = (a1, b1)
    (c1, b1) = (b1, c1)
elif c1 <= b1 <= a1:
    (c1, a1) = (a1, c1)
elif c1 <= a1 <= b1:
    (c1, a1) = (a1, c1)
    (b1, c1) = (c1, b1)
if a2 <= c2 <= b2:
    (c2, b2) = (b2, c2)
elif b2 <= a2 <= c2:
    (b2, a2) = (a2, b2)
elif b2 <= c2 <= a2:
    (b2, a2) = (a2, b2)
    (c2, b2) = (b2, c2)
elif c2 <= b2 <= a2:
    (c2, a2) = (a2, c2)
elif c2 <= a2 <= b2:
    (c2, a2) = (a2, c2)
    (b2, c2) = (c2, b2)
# print(a1, b1, c1)  # Проверяем корректность работы функции (a,b)=(b,a)
# print(a2, b2, c2)  # Проверяем корректность работы функции (a,b)=(b,a)
if (a1 <= a2) and (b1 <= b2) and (c1 < c2):
    print('The first box is smaller than the second one')
elif (a1 <= a2) and (b1 < b2) and (c1 <= c2):
    print('The first box is smaller than the second one')
elif (a1 < a2) and (b1 < b2) and (c1 <= c2):
    print('The first box is smaller than the second one')
elif (a1 == a2) and (b1 == b2) and (c1 == c2):
    print('Boxes are equal')
elif (a1 >= a2) and (b1 >= b2) and (c1 > c2):
    print('The first box is larger than the second one')
elif (a1 >= a2) and (b1 > b2) and (c1 >= c2):
    print('The first box is larger than the second one')
elif (a1 > a2) and (b1 >= b2) and (c1 >= c2):
    print('The first box is larger than the second one')
else:
    print('Boxes are incomparable')

# %% [markdown]
# ### Задача
#
# Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3 (если все совпадают), 2 (если два совпадает) или 0 (если все числа различны).

# %%
a, b, c = int(input()), int(input()), int(input())
if a == b and a == c and b == c:
    print(3)
elif a == b or a == c or b == c:
    print(2)
else:
    print(0)

# %% [markdown]
# ### Задача
#
# Шоколадка имеет вид прямоугольника, разделенного на n×m долек. Шоколадку можно один раз разломить по прямой на две части. Определите, можно ли таким образом отломить от шоколадки часть, состоящую ровно из k долек. На входе три числа: n, m, k. На выходе должно быть одно из двух слов: YES или NO.

# %%
n = int(input())
m = int(input())
k = int(input())
if k < n * m:
    if k % n == 0 or k % m == 0:
        print('YES')
    else:
        print('NO')
else:
    print('NO')

# %% [markdown]
# ### Задача
#
# Дано натуральное число. Требуется определить, является ли год с данным номером високосным. Если год является високосным, то выведите YES, иначе выведите NO. Напомним, что в соответствии с григорианским календарем, год является високосным, если его номер кратен 4, но не кратен 100, или же если он кратен 400.

# %%
a = int(input())
if a % 400 == 0:
    print('YES')
else:
    if a % 100 == 0:
        print('NO')
    else:
        if a % 4 == 0:
            print('YES')
        else:
                print('NO')

# %% [markdown]
# ### Задача
#
# Для данного числа 0<=n<=100 закончите фразу "У меня на этой неделе..." одним из возможных продолжений: "n дедлайн", "n дедлайна", "n дедлайнов", правильно склоняя слово "дедлайн".

# %%
n = int(input())
if (11 <= n <= 14) or (5 <= n % 10 <= 9) or (n % 10 == 0):
    print(n, "дедлайнов")
elif n % 10 == 1:
    print(n, "дедлайн")
else:
    print(n, "дедлайна")

# %% [markdown]
# Для данного числа n<100 закончите фразу “На лугу пасется...” одним из возможных продолжений: “n коров”, “n корова”, “n коровы”, правильно склоняя слово “корова”. Программа должна вывести введенное число n и одно из слов: korov, korova или korovy. Между числом и словом должен стоять ровно один пробел.

# %%
n = int(input())
if n > 20 and 2 <= (n % 10) <= 4:
    print(n, 'korovy')
elif n % 10 == 1 and n != 11:
    print(n, 'korova')
elif n < 10 and 2 <= (n % 10) <= 4:
    print(n, 'korovy')
else:
    print(n, 'korov')

# %% [markdown]
# # Встроенные функции
#
# В программировании (и в Python, в частности) функция — это сущность, которая из одного (или даже нескольких) значений делает другое.
#
# На прошлых занятии мы познакомились с несколькими:
#
# `print` -  выводит свои аргументы на экран. Функция может принимать не один аргумент, а сколько угодно. Несколько аргументов одной функции следует разделять запятыми.
#
# `input` — тоже функция, может работать, не принимая никаких аргументов, а может в качестве аргумента принимать сообщение, которое надо вывести перед ожиданием пользовательского ввода. Но всегда считывает строку с клавиатуры и возвращает ее.
#
# `str` - переводит объект в строку
#
# `int` - преобразовывает к типу integer

# %%
print(int(20.5 + 34.1))  # Дробная часть отбрасывается

# %%
print(int(input()) + 1)

# %% [markdown]
# `float` поможет, если строка, которую надо конвертировать в число, не является целым числом

# %%
pi_digits = '3.141592653589793238462643383279502884197169399375'
print(float(pi_digits))

# %% [markdown]
# `round()`  - используется для так называемого "банковского округления", то есть округление к ближайшему чётному.

# %%
round(3.5)

# %%
round(2.5)

# %%
print(round(2.5)) 
print(round(3.1))

# %%
print(round(3))

# %% [markdown]
# `len()` - определяет длину строки (количества символов в стоке)

# %%
word = input()
length = len(word)
print('Вы ввели слово длиной', length, 'букв.')

# %% [markdown]
# `type()` - возвращает тип объекта, который вы ей передаете

# %%
type(True)

# %% [markdown]
# `help()` - хотите знать, как работает определённый объект, метод или атрибут, функция help поможет вам.

# %%
# ?print

# %%
help(print)

# %% [markdown]
# Использование в программе функции называется вызов функции, а данные, записанные в круглых скобках - аргументами. После выполнения работы на место вызова функции (то есть имени функции и ее аргументов в скобках) подставляется результат ее работы, это называется возвращаемое значение функции.

# %% [markdown]
# # Встроенные модули
#
# Стандартных библиотек, входящей в комплект Python, уже достаточно для многих реализации множества действий. Стандартным библиотекам посвящен целый раздел документации: https://docs.python.org/3/library/
#
# Чтобы воспользоваться функциями, в составе каких-либо модулей, их необходимо подключить - импортировать. За импорт в Python отвечает директива `import`.

# %%
import numpy
print(numpy.pi)  # Вызов конкретной функции из импортированной библиотеки

# %%
from math import pi  # Возьмем число пи из библиотеки math
print(pi)

# %%
# !pip install opencv-python  # Команда установки новой библиотеки opencv-python

# %% [markdown]
# Если ошибка pip.
#
# Откройте Anaconda, далее нужно открыть терминал и вести команду:
#
# python -m pip install --upgrade pip
#
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/07.png?raw=true)

# %% [markdown]
# # Ключевое слово as

# %%
import math as m  # После данной команды, вместо math.log, можно писать более кратко:

# %%
m.log(80)

# %%
from math import log  # Импортировав функцию log, указывать через точку имя библиотеки math, больше не нужно:

# %%
log(80)

# %% [markdown]
# Модуль, переменную, класс или функцию можно при импорте назвать своим именем — для этого служит ключевое слово `as`, например:

# %%
from math import pi as число_пи
число_пи

# %% [markdown]
# Более того, поскольку в программе на языке Python в именах допустимы буквенные символы любых алфавитов, можно использовать даже греческие буквы (впрочем, это неудобно, если у вас кириллическо-латинская клавиатура).

# %%
from math import pi as π
print(π)

# %% [markdown]
# Мы можем импортировать всю библиотеку, но тогда для доступа к ее содержимому нужно снова использовать точку:

# %%
import math
print(math.pi)

# %% [markdown]
# # Особенности импорта модулей
#
# Значения после директивы `import` можно писать через запятую:

# %%
from math import sin, cos, tan

# %%
sin(0.5)

# %% [markdown]
# Значок `*` означает, что из библиотеки нужно импортировать всё, что доступно.

# %%
from math import *

# %%
cos(50)

# %% [markdown]
# Но так делать не рекомендуется, поскольку при таком подходе засоряется пространство имен.

# %%
help(sin)

# %%
help(radians)

# %%
sin(radians(90))

# %%
help(math)  # Просмотр справки по библиотеке и всех входящих в неё функций

# %%
conda list  # Команда для просмотра всех установленных библиотек и их версий

# %% [markdown]
# # Цикл While

# %% [markdown]
# `While` - один из самых универсальных циклов в Python, но работает достаточно медленно.
#
# Цикл while (в переводе - пока) позволяет выполнить одну и ту же последовательность действий, пока проверяемое условие истинно.
#
# Как правило, цикл while используется, когда невозможно определить точное значение количества проходов исполнения цикла.
#
# Условие записывается до тела цикла и проверяется до выполнения тела цикла.
#
# При выполнении цикла while сначала проверяется условие. Если оно ложно, то выполнение цикла прекращается и управление передается на следующую инструкцию после тела цикла while. Если условие истинно, то выполняется инструкция, после чего условие проверяется снова и снова выполняется инструкция. Так продолжается до тех пор, пока условие будет истинно. Как только условие станет ложно, работа цикла завершится и управление передастся следующей инструкции после цикла.
#
# Синтаксис цикла while в простейшем случае выглядит так:

# %%
while <<условие>> :
    <<блок инструкций>>

# %% [markdown]
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/08.png?raw=true)

# %% [markdown]
# ### Задача
#
# Вывести все числа от 1 до заданного пользователем целого числа N с помощью цикла while

# %%
N = int(input())
i = 1
while i <= N:
    print(i)
    i += 1  # Переменная i увеличивается на 1 и перезаписывается. Раносильная запись i = i + 1

# %% [markdown]
# ### Задача
# Посчитать из скольки цифр состоит натуральное число, введенное пользователем с клавиатуры с помощью цикла while

# %%
N = int(input())
count = 0
while N > 0:
    print(N)
    N //= 10
    count += 1
print()
print(count)

# %% [markdown]
# ### Задача
# Используя цикл while, выведите на экран для числа 2 его степени от 0 до 10.

# %%
i = 0
while i <= 10:
    print(2 ** i)
    i += 1

# %% [markdown]
# ### Задача
#
# Программа по вычислению факториала натурального числа, заданного пользователем.
#
# 5! = 1\*2\*3\*4\*5

# %%
N = int(input())
i = 1
f = 1
while i <= N:
    f *= i
    i += 1
print(f)

# %% [markdown]
# ### Задача
#
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.

# %%
n = int(input())
i = 2
while n % i != 0:
    i += 1
print(i)

# %% [markdown]
# ### Задача
#
# Игра-угадайка.
#
# Программа будет загадывать целое число от 1 до 100, а пользователь его угадывать. Будем генерировать случайное число n из интервала [1, 100]. Задача пользователя угадать это число. Выводится количество попыток сделанное пользователем.

# %%
from random import randrange  # Ипортируем функию randrange
n = randrange(1, 101)  # n и есть загаданное число. Указываем 101, т.к. последнее значение диапазона, не используется
print(n)

# %%
num = 1  # Служит счётчиком попыток угадать число
flag = True
while flag:
    print("Ваша попытка", num, "Ваше число: ", end = "")
    guess = int(input())
    if guess == n:
        print("Вы выиграли")
        flag = False
    elif guess > n:
        print("Вы ввели слишком большое число")
        num += 1
    else:
        print("Вы ввели слишком маленькое число")
        num += 1
print(f"Было совершено {num} попыток")

# %% [markdown]
# # Инструкции, использующиеся внутри циклов
#
# `break` – производит переход за пределы цикла
#
# `continue` – производит переход в начало цикла
#
# `pass` – ничего не делает (пустая конструкция-заполнитель)
#
# `else` – выполняется, только если цикл завершился обычным образом (без использования break)

# %%
i = 0

while i <= 5:
    print(i)
    if i == 3:
        break  # Полностью выводит нас из цикла
    i += 1
else:
    print("Цикл завершил работу")

# %%
i = 0

while i <= 5:
    i += 1
    
    if i == 3:
        print("Тройку пропускаем")
        continue  # Пропускаем дальнеший код в теле цикла и возвращаемся к началу
        
    print(i)
else:
    print("Цикл завершил работу")

# %%
i = 0

while i <= 10:
    if i == 5:
        pass  # Ничего не делаем
    else:
        print(i)
    i += 1
else:
    print("Цикл завершил работу")

# %% [markdown]
# # Вложенные циклы

# %% [markdown]
# ![Ошибка загрузки](https://github.com/akazachkov/python_notebook/blob/master/python_lectures/_pic_lesson_python/09.png?raw=true)

# %% [markdown]
# Вложенные циклы while содержат два основных компонента:
#
# 1. Внешний цикл while
# 2. Внутренний цикл while
#
#
# Внешний цикл while может содержать несколько внутренних циклов while. Условие приводит к булевому значению, и если оно истинно, только тогда цикл выполняется. На каждой итерации внешнего цикла while внутренний цикл выполняется с самого начала, и этот процесс продолжается до тех пор, пока условие внешнего цикла не станет истинным. Аналогично, внутренний цикл while выполняется только в том случае, если его условие истинно, после чего выполняется блок кода.

# %% [markdown]
# ### Задача
#
# Выведите таблицу умножения от 1 до 5.

# %%
i = 1

while i <= 5:
    j = 1
    while j <= 10:
        print(i, "*", j, "=", i * j)
        j += 1
    print()
    i += 1
